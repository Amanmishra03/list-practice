# %% [markdown]
# Write a program that creates a list of integers and then sorts the list in descending order. Print the sorted list.

# %%
l1 = []
user = int(input('enter no. you want '))

for i in range (user):
    x = int(input('enter the no. in list '))
    l1.append(x)


print(l1)   

sorted_list = l1.sort(reverse=True)
print(l1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       2 user = int(input('enter no. you want '))
#       4 for i in range (user):
# ----> 5     x = int(input('enter the no. in list '))
#       6     l1.append(x)
#       9 print(l1)
#
# ValueError: invalid literal for int() with base 10: '5,6,5,6'
